# %%
# !git clone https://github.com/jaydentang895/FallDetectionData.git
# Out:
# Cloning into 'FallDetectionData'...
# remote: Enumerating objects: 17498, done.
# remote: Counting objects: 100% (1920/1920), done.
# remote: Compressing objects: 100% (1844/1844), done.
# remote: Total 17498 (delta 15), reused 1917 (delta 15), pack-reused 15578
# Receiving objects: 100% (17498/17498), 393.55 MiB | 24.02 MiB/s, done.
# Resolving deltas: 100% (15/15), done.
# Updating files: 100% (15565/15565), done.

# %%
# !pip install ultralytics
# Out:
# ...
#   Obtaining dependency information for ultralytics from https://files.pythonhosted.org/packages/14/db/f1ec308131cf4bf2f5f3a43a679dbef06e67e45525492be551b21e9e19d7/ultralytics-8.1.6-py3-none-any.whl.metadata
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.2/40.2 kB 2.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 705.0/705.0 kB 21.7 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO

modelpath = '/kaggle/working/FallDetectionData/yolov8n_fall.yaml'
datapath = '/kaggle/working/FallDetectionData/fall.yaml'

# Load a model
model = YOLO(modelpath)  # build a new model from YAML
model = YOLO('yolov8n.pt')  # load a pretrained model (recommended for training)
model = YOLO(modelpath).load('yolov8n.pt')  # build from YAML and transfer weights

# Train the model
results = model.train(data=datapath, epochs=100, imgsz=640)
# Out:
# ...
# 100%|██████████| 6.23M/6.23M [00:00<00:00, 115MB/s]
# Transferred 319/355 items from pretrained weights
# Ultralytics YOLOv8.1.6 🚀 Python-3.10.12 torch-2.0.0 CUDA:0 (Tesla P100-PCIE-16GB, 16276MiB)
# ...
